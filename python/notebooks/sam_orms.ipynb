# %%
import sys
import os

# Get the absolute path to the directory containing your modules
module_path = os.path.abspath('..')

# Insert the path at the beginning of sys.path
sys.path.insert(0, module_path)

# Now you can import modules from that directory
import sam
from sam.session import create_sam_engine, get_session

engine, SessionLocal = create_sam_engine()
# Out:
# hpc-reader:$SAM_DB_PASSWORD@sam-sql.ucar.edu/sam

# %%
from sam.queries import *
from sam.queries.examples import example_usage
example_usage()
# Out:
# Found user: Benjamin Shelton Kirk
# Primary GID: 1000
# Primary email: benkirk@ucar.edu
# All emails: benkirk@ucar.edu
#
# Detailed email information:
#   - benkirk@ucar.edu
# SCSG0001 - CSG systems project
# NCGD0058 - Software Engineering At Scale (SEAS) ** INACTIVE **
# UESM0011 - 2022 CESM tutorial August 8-12 ** INACTIVE **
# UCIS0004 - GPU Training Allocation for Workshop ** INACTIVE **
#
# --- Users with multiple emails ---: 19530
# mriachy (Mansour Riachy): 2 emails
#   - mriachy@ucar.edu
#   - mriachy@albany.edu
# ancheung (Anson Cheung): 2 emails
#   - ancheung@ucar.edu
#   - ahc2182@columbia.edu
# kspeer (Kevin Speer): 2 emails
#   - kspeer@ucar.edu
#   - kspeer@fsu.edu
# bslee (Benjamin Seiyon Lee): 2 emails
#   - bslee@ucar.edu
#   - slee287@gmu.edu
# horvatch (Christopher Horvat): 2 emails
#   - horvatch@ucar.edu
#   - horvat@brown.edu
#
# --- Users without primary email ---
# Found 1181 active users without a primary email
#   kholden: kholden@ucar.edu
#   emmons: emmons@ucar.edu
#   maclean: maclean@ucar.edu
#   linden: linden@ucar.edu
#   rcabell: rcabell@ucar.edu
#
# --- Project Details ---
# Project: SCSG0001
# Title: CSG systems project
# Lead: Benjamin Shelton Kirk
#
# Allocations by resource:
#   Data_Access: 1.00 (expires 2026-09-30 23:59:59)
#   HPC_Futures_Lab: 1.00 (expires 2026-09-30 23:59:59)
#   Campaign_Store: 20.00 (expires 2026-09-30 23:59:59)
#   Casper: 50,000.00 (expires 2026-09-30 23:59:59)
#   Stratus: 100.00 (expires 2026-09-30 23:59:59)
#   Casper GPU: 10,000.00 (expires 2026-09-30 23:59:59)
#   Derecho: 100,000,000.00 (expires 2026-09-30 23:59:59)
#   Derecho GPU: 1,000,000.00 (expires 2026-09-30 23:59:59)
#   Gust: 5,000.00 (expires 2026-09-30 23:59:59)
#   Gust GPU: 1,000.00 (expires 2026-09-30 23:59:59)
#
# Specific Allocation by resource:
#   Derecho: 100,000,000.00 (expires 2026-09-30 23:59:59)
# Roster (12):
# benkirk
# klefevre
# csgteam
# rory
# valent
# biswas
# bneuman
# negins
# cmipap
# dhoward
# vanderwb
# mtrahan
#
# --- Available Resources ---
#   HPSS                 (ARCHIVE   ) DECOMMISSIONED
#   CMIP Analysis Platform (DATA ACCESS) ACTIVE
#   Data_Access          (DATA ACCESS) ACTIVE
#   hpc-dev              (DATA ACCESS) ACTIVE
#   Anemone              (DAV       ) DECOMMISSIONED
#   Casper               (DAV       ) ACTIVE
#   Geyser_Caldera       (DAV       ) DECOMMISSIONED
#   Pronghorn            (DAV       ) DECOMMISSIONED
#   Yogi_Booboo          (DAV       ) DECOMMISSIONED
#   Campaign_Store       (DISK      ) ACTIVE
#   GLADE fs1 (Cheyenne) (DISK      ) DECOMMISSIONED
#   GLADE user           (DISK      ) ACTIVE
#   GLADE work           (DISK      ) ACTIVE
#   Quasar               (DISK      ) ACTIVE
#   Stratus              (DISK      ) ACTIVE
#   Bluefire             (HPC       ) DECOMMISSIONED
#   BlueM                (HPC       ) DECOMMISSIONED
#   Casper GPU           (HPC       ) ACTIVE
#   Cheyenne             (HPC       ) DECOMMISSIONED
#   Derecho              (HPC       ) ACTIVE
#   Derecho GPU          (HPC       ) ACTIVE
#   Erebus               (HPC       ) DECOMMISSIONED
#   Gust                 (HPC       ) ACTIVE
#   Gust GPU             (HPC       ) ACTIVE
#   hpc                  (HPC       ) ACTIVE
#   HPC_Futures_Lab      (HPC       ) ACTIVE
#   Janus                (HPC       ) DECOMMISSIONED
#   Jellystone           (HPC       ) DECOMMISSIONED
#   Laramie              (HPC       ) ACTIVE
#   Lynx                 (HPC       ) DECOMMISSIONED
#   Yellowstone          (HPC       ) DECOMMISSIONED
#
# --- Projects Expiring Soon (30 days, all resources) ---
# Found 26 allocations expiring
#   NHAO0031 (Data_Access): 10 days remaining
#   UAUB0012 (Casper): 10 days remaining
#   UCCN0003 (Campaign_Store): 10 days remaining
#   UCIR0047 (Campaign_Store): 10 days remaining
#   UCLA0033 (Derecho): 10 days remaining
#
# --- Derecho Allocations Expiring Soon (30 days) ---
# Found 21 Derecho allocations expiring
#   UAUB0012: 10 days remaining (expires 2025-11-30)
#   UCIR0047: 10 days remaining (expires 2025-11-30)
#   UCLA0033: 10 days remaining (expires 2025-11-30)
#   UCLB0049: 10 days remaining (expires 2025-11-30)
#   UCSU0092: 10 days remaining (expires 2025-11-30)
#
# --- User Statistics ---
#   total_users: 27234
#   active_users: 5691
#   locked_users: 0
#   inactive_users: 21543
#
# --- Project Statistics ---
#   Total: 5467
#   Active: 1424
#   By Facility:
#     CISL: 11
#     NCAR: 148
#     UNIV: 1186
#     CSL: 20
#     WNA: 57
#     ASD: 2
#
# --- Project Access for rcabell ---
# Total projects: 17
#   P48500028: Admin
#   NRAL0017: Lead
#   NRAL0027: Admin
#   NSAP0003: Member
#   NMMM0013: Member
#   NSAP0002: Member
#   NSAP0003: Member
#   NSAP0003: Member
#   NMMM0013: Member
#   NSAP0002: Member
#   NMMM0013: Member
#   NSAP0003: Member
#   NSAP0003: Member
#   NMMM0013: Member
#   NMMM0013: Member
#   NSAP0002: Member
#   NSAP0002: Member
# 6 6
#
# --- Users on Project SCSG0001 ---
#   Lead     benkirk      Ben Kirk             <benkirk@ucar.edu>
#   Member   biswas       Mrinal Biswas        <biswas@ucar.edu>
#   Member   bneuman      Brett Neuman         <bneuman@ucar.edu>
#   Member   cmipap       Ben Kirk             <None>
#   Member   csgteam      Ben Kirk             <None>
#   Member   dhoward      Daniel Howard        <dhoward@ucar.edu>
#   Member   klefevre     Karla LeFevre        <klefevre@ucar.edu>
#   Member   mtrahan      Mea Trahan           <mtrahan@ucar.edu>
#   Member   negins       Negin Sobhani        <negins@ucar.edu>
#   Member   rory         Rory Kelly           <rory@ucar.edu>
#   Member   valent       Richard Valent       <valent@ucar.edu>
#   Member   vanderwb     Brian Vanderwende    <vanderwb@ucar.edu>

# %%
with get_session(SessionLocal) as session:
    print(get_project_statistics(session))
    print(get_institution_project_count(session))
    print(get_project_usage_summary(session, 'SCSG0001',
            datetime(2024, 1, 1),
            datetime(2024, 12, 31),
            "Derecho"))
    print(get_jobs_for_project(session, "SCSG0001", 
            datetime(2024, 1, 1),
            datetime(2024, 12, 31),
            "Derecho", 100))
# Out:
# {'total_projects': 5467, 'active_projects': 1424, 'inactive_projects': 4043, 'by_facility': {'CISL': 11, 'NCAR': 148, 'UNIV': 1186, 'CSL': 20, 'WNA': 57, 'ASD': 2}}
# [{'institution': 'UNIVERSITY OF COLORADO AT BOULDER', 'project_count': 111}, {'institution': 'UNIVERSITY OF WASHINGTON', 'project_count': 98}, {'institution': 'UNIVERSITY OF MICHIGAN', 'project_count': 73}, {'institution': 'UNIVERSITY OF WYOMING', 'project_count': 68}, {'institution': 'UNIVERSITY OF CALIFORNIA LOS ANGELES', 'project_count': 60}, {'institution': 'COLORADO STATE UNIVERSITY', 'project_count': 57}, {'institution': 'COLUMBIA UNIVERSITY', 'project_count': 53}, {'institution': 'UNIVERSITY OF ILLINOIS', 'project_count': 52}, {'institution': 'CORNELL UNIVERSITY', 'project_count': 47}, {'institution': 'UNIVERSITY OF CALIFORNIA AT SAN DIEGO', 'project_count': 46}, {'institution': 'NORTH CAROLINA STATE UNIVERSITY', 'project_count': 45}, {'institution': 'UNIVERSITY OF WISCONSIN AT MADISON', 'project_count': 43}, {'institution': 'UNIVERSITY OF HAWAII AT MANOA', 'project_count': 41}, {'institution': 'PRINCETON UNIVERSITY', 'project_count': 41}, {'institution': 'YALE UNIVERSITY', 'project_count': 38}, {'institution': 'SCRIPPS INSTITUTION OF OCEANOGRAPHY', 'project_count': 38}, {'institution': 'PENNSYLVANIA STATE UNIVERSITY', 'project_count': 37}, {'institution': 'MASSACHUSETTS INSTITUTE OF TECHNOLOGY', 'project_count': 37}, {'institution': 'UNIVERSITY OF MARYLAND', 'project_count': 36}, {'institution': 'PURDUE UNIVERSITY', 'project_count': 35}]
# {'total_jobs': Decimal('16443'), 'total_core_hours': 5391401.2887342, 'total_charges': 5631991.54179543}

# %%
#### with get_session(SessionLocal) as session:
    # Find a user
    user = find_user_by_username(session, 'benkirk')
    if user:
        print(f"Found user: {user.full_name}")
        print(f"Primary GID: {user.primary_gid}")
        print(f"Primary email: {user.primary_email}")
        print(f"All emails: {', '.join(user.all_emails)}")

        # Get detailed email info
        print("Detailed email information:")
        for email_info in user.get_emails_detailed():
            primary_marker = " (PRIMARY)" if email_info['is_primary'] else ""
            active_marker = "" if email_info['active'] else " (INACTIVE)"
            print(f"  - {email_info['email']}{primary_marker}{active_marker}")

        # Find projects
        print("Detailed project information:")
        for p in user.all_projects:
            label = "" if p.active else " ** INACTIVE **"
            print(f"  {p.projcode}, {p.title}{label}")

# %%
def project_details(project):
    if project:
        print(f"--- Project Details ---")
        print(f"Project: {project.projcode}")
        print(f"Title: {project.title}")
        print(f"Lead: {project.lead.full_name}")
        if project.admin and project.lead != project.admin:
           print(f"Admin: {project.admin.full_name}") 
        for d in project.directories:
            label = "" if d.is_currently_active else " ** INACTIVE **"
            print(f"  Directory: {d.directory_name}{label}")
        # Show allocations by resource
        print(f"Allocations by resource:")
        allocs_by_resource = project.get_all_allocations_by_resource()        
        for resource_name, alloc in allocs_by_resource.items():
            resource = Resource.get_by_name(session,resource_name)
            label = "" if resource.is_active else " ** INACTIVE RESOURCE??? **"
            print(f"  {resource_name:12}: {alloc.amount:,.0f} (expires {alloc.end_date.date()}){label}")

        # Show users on project
        print(f"Roster:")
        for user in project.roster:
            print(f"  {user.username:12} {user.display_name:30} <{user.primary_email}>")

# %%
with get_session(SessionLocal) as session:
    # Find a project
    project = get_project_with_full_details(session, 'SCSG0001')
    project_details(project)

# %%
from datetime import timedelta

with get_session(SessionLocal) as session:
    # Get expiring projects (simple) - all resources
    print("\n--- Projects Expiring Soon (30 days, all resources) ---")
    expiring = get_projects_expiring_soon(session, days=30)
    expiring = get_projects_by_allocation_end_date(session, 
                                                   start_date=datetime.now(),
                                                   end_date=datetime.now() + timedelta(days=30),                                                   
                                                   facility_names=['UNIV', 'WNA'])
    #expiring = list(set(expiring))
    print(f"Found {len(expiring)} allocations expiring")
    for proj, alloc, res_name, days in expiring:
        print(f"\n{proj.projcode} / {days} days remaining")
        project_details(proj)

# %%
projcode='SCSG0001'
start_date = datetime(2024, 1, 1)
end_date = datetime(2024, 12, 31)
resource='Casper'

with get_session(SessionLocal) as session:

    top_users = get_user_usage_on_project(        
                    session, projcode,
                    start_date,
                    end_date,
                    limit=5)
    for user in top_users:
        print(f"{user['username']:12}: {user['charges']:.2f}")
                
    usage = get_project_usage_summary(session,
                                      projcode,
                                      start_date,
                                      end_date,
                                      resource)
    #print(usage)
    print(f"Project {projcode} ran {usage['total_jobs']} and used {usage['total_core_hours']:2f} core hours")

    trend = get_daily_usage_trend(session,
                                  projcode,
                                  start_date,
                                  end_date,
                                  resource)
    for day in trend[:5]:
        print(f"{day['date']}: {day['jobs']} jobs, {day['charges']} charges")

# %%
with get_session(SessionLocal) as session:
    for projcode in [ 'CESM0002', 'CESM0028', 'P93300065' ]:
        # Find a project
        project = get_project_with_full_details(session, projcode)
        project_details(project)    

        ancestors = project.get_ancestors()
        print(f"Ancestors: {[p.projcode for p in ancestors]}")

        # Navigate down the tree
        descendants = project.get_descendants()
        print(f"All descendants: {len(descendants)}")
        print(project.print_tree())

# %%
with get_session(SessionLocal) as session:
    
    active_users = User.get_active_users(session)
    print(len(active_users))
    #for user in active_users:
    #    for project in user.projects:
    #        print(user,project)            

    active_projects = Project.get_active_projects(session)
    print(len(active_projects))

# %%
from datetime import datetime, timedelta
with get_session(SessionLocal) as session:
    # Get expiring projects (simple) - all resources
    #print("\n--- Projects Post-Expiry (90 days after, all resources) ---")
    all_users = set()
    orphaned_users = set()
    expiring_projects = set()
    expiring = get_projects_with_expired_allocations(session,
                                                     max_days_expired=90,
                                                     min_days_expired=365,    
                                                     facility_names=['UNIV', 'WNA'])

    #expiring = list(set(expiring))
    print(f"Found {len(expiring)} recently expired projects:")
    #print(expiring)
    for proj, alloc, res_name, days in expiring:
        #allocs_by_resource = proj.get_all_allocations_by_resource()
        #if allocs_by_resource: continue
        print(f" {proj.projcode} - {days} days since expiration")
        #print(alloc)
        #project_details(proj)
        all_users.update(proj.roster)
        expiring_projects.add(proj.projcode)

    for user in all_users:
        user_projects = set()
        #print(user.display_name)
        for proj in user.active_projects:
            user_projects.add(proj.projcode)
            #print("  > ",proj.projcode)
        if user_projects.issubset(expiring_projects): orphaned_users.add(user)

    print(f"\nFound {len(orphaned_users)} expiring users:")
    for user in orphaned_users:
        #print(user)
        print(f" {user.username:12} {user.display_name:20} <{user.primary_email}>")
